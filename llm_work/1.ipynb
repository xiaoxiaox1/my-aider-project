# %%
print("hello world")

# %% [markdown]
# | 项目 | 数量 | 价格 |
# |------|------|------|
# | 苹果 | 10   | 5.0  |
# | 香蕉 | 15   | 3.5  |
# | 橙子 | 8    | 4.2  |
# | 葡萄 | 12   | 6.8  |
# |      |      |      |
# | **10个苹果总价** |      | **50.0元** |
